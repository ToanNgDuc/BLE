# %%
import numpy as np
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split

def Normalization(data_matrix):
    #data_matrix = data.to_numpy()
    x_min = np.min(data_matrix)
    x_max = np.max(data_matrix)
    x_norm = (data_matrix-x_min)/(x_max-x_min)

    return x_norm, x_max, x_min

# %%
dataset = pd.read_csv('E:/Định Vị - ESP32/Data_test13_9.csv')
data = dataset.iloc[:, :1200]
train_data = np.array(data)
min_val = tf.reduce_min(train_data)
max_val = tf.reduce_max(train_data)
train_data = (train_data - min_val) / (max_val - min_val)
train_data.numpy()
# Out:
# array([[0.82051282, 0.82051282, 0.82051282, ..., 0.41025641, 0.38461538,
#         0.38461538],
#        [0.53846154, 0.61538462, 0.69230769, ..., 0.38461538, 0.43589744,
#         0.35897436],
#        [0.69230769, 0.30769231, 0.38461538, ..., 0.46153846, 0.28205128,
#         0.43589744],
#        ...,
#        [0.41025641, 0.38461538, 0.38461538, ..., 0.35897436, 0.53846154,
#         0.51282051],
#        [0.33333333, 0.33333333, 0.46153846, ..., 0.30769231, 0.25641026,
#         0.15384615],
#        [0.53846154, 0.53846154, 0.41025641, ..., 0.23076923, 0.30769231,
#         0.28205128]])

# %%
class FingerPrint_Extraction(Model):
  def __init__(self):
      super(FingerPrint_Extraction, self).__init__()
      self.encoder = tf.keras.Sequential([
          layers.Dense(1200, activation = 'tanh'),
          layers.Dense(1000, activation = 'tanh'),
          layers.Dense(800, activation = 'tanh'),
          layers.Dense(600, activation = 'tanh'),
          layers.Dense(400, activation = 'tanh'),
          layers.Dense(200, activation = 'tanh'),
          layers.Dense(12, activation = 'tanh')])
      self.decoder = tf.keras.Sequential([
          layers.Dense(12, activation = 'tanh'),
          layers.Dense(200, activation = 'tanh'),
          layers.Dense(400, activation = 'tanh'),
          layers.Dense(600, activation = 'tanh'),
          layers.Dense(800, activation = 'tanh'),
          layers.Dense(1000, activation = 'tanh'),
          layers.Dense(1200, activation = 'tanh')])
  
  def call(self, x):
      encoded = self.encoder(x)
      decoded = self.decoder(encoded)
      return decoded



  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = FingerPrint_Extraction()
autoencoder = FingerPrint_Extraction()
autoencoder.compile(optimizer = 'adam', loss = 'mae')

# %%
df = pd.DataFrame()
for i in range(75):
    train_data_i = train_data[i]
    train_data_i = train_data_i.numpy()
    train_data_i = train_data_i.reshape(1,1200)
    history = autoencoder.fit(train_data_i, train_data_i, 
          epochs=200, 
          batch_size=256,
          shuffle=True)
    encoded_data_i = autoencoder.encoder(train_data_i).numpy()
    decoded_data_i = autoencoder.decoder(encoded_data_i).numpy()
    decoded_df_i = pd.DataFrame(decoded_data_i)
    df = pd.concat([df, decoded_df_i], axis = 0)
    print(i)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.4525
# Epoch 2/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3702
# Epoch 3/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2344
# Epoch 4/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1719
# Epoch 5/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1490
# Epoch 6/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1365
# Epoch 7/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1054
# Epoch 8/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1017
# Epoch 9/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0884
# Epoch 10/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0671
# Epoch 11/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0673
# Epoch 12/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0706
# Epoch 13/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0516
# Epoch 14/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0574
# Epoch 15/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0631
# Epoch 16/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0445
# Epoch 17/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0592
# Epoch 18/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0437
# Epoch 19/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0422
# Epoch 20/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0471
# Epoch 21/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0351
# Epoch 22/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0420
# Epoch 23/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0324
# Epoch 24/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0313
# Epoch 25/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0356
# Epoch 26/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0258
# Epoch 27/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0267
# Epoch 28/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0326
# Epoch 29/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0244
# Epoch 30/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0257
# Epoch 31/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0309
# Epoch 32/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0227
# Epoch 33/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0249
# Epoch 34/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0287
# Epoch 35/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0211
# Epoch 36/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0228
# Epoch 37/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0279
# Epoch 38/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0201
# Epoch 39/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0217
# Epoch 40/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0272
# Epoch 41/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0188
# Epoch 42/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0217
# Epoch 43/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0256
# Epoch 44/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0183
# Epoch 45/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0227
# Epoch 46/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0251
# Epoch 47/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0186
# Epoch 48/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0221
# Epoch 49/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0209
# Epoch 50/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0163
# Epoch 51/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0169
# Epoch 52/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0208
# Epoch 53/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0187
# Epoch 54/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0163
# Epoch 55/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0162
# Epoch 56/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0186
# Epoch 57/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0186
# Epoch 58/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0151
# Epoch 59/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0137
# Epoch 60/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0159
# Epoch 61/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0203
# Epoch 62/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0172
# Epoch 63/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0147
# Epoch 64/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0156
# Epoch 65/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0190
# Epoch 66/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0176
# Epoch 67/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0147
# Epoch 68/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0136
# Epoch 69/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0160
# Epoch 70/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0201
# Epoch 71/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0162
# Epoch 72/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0144
# Epoch 73/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0170
# Epoch 74/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0186
# Epoch 75/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0157
# Epoch 76/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0130
# Epoch 77/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0133
# Epoch 78/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0188
# Epoch 79/200
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0192
# Epoch 80/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0144
# Epoch 81/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0164
# Epoch 82/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0188
# Epoch 83/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0159
# Epoch 84/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0135
# Epoch 85/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0148
# Epoch 86/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0182
# Epoch 87/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0162
# Epoch 88/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0135
# Epoch 89/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0139
# Epoch 90/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0176
# Epoch 91/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0159
# Epoch 92/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0130
# Epoch 93/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0121
# Epoch 94/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0134
# Epoch 95/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0178
# Epoch 96/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0158
# Epoch 97/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0129
# Epoch 98/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0135
# Epoch 99/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0176
# Epoch 100/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0153
# Epoch 101/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0129
# Epoch 102/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0116
# Epoch 103/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0118
# Epoch 104/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0175
# Epoch 105/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0171
# Epoch 106/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0139
# Epoch 107/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0155
# Epoch 108/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0182
# Epoch 109/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0139
# Epoch 110/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0118
# Epoch 111/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0134
# Epoch 112/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0177
# Epoch 113/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0152
# Epoch 114/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0130
# Epoch 115/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0149
# Epoch 116/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0147
# Epoch 117/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0142
# Epoch 118/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0139
# Epoch 119/200
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0134
# Epoch 120/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0133
# Epoch 121/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0126
# Epoch 122/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0122
# Epoch 123/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0137
# Epoch 124/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0158
# Epoch 125/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0135
# Epoch 126/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0112
# Epoch 127/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0102
# Epoch 128/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0135
# Epoch 129/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0196
# Epoch 130/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0136
# Epoch 131/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0139
# Epoch 132/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0198
# Epoch 133/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0130
# Epoch 134/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0137
# Epoch 135/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0199
# Epoch 136/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0131
# Epoch 137/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0129
# Epoch 138/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0193
# Epoch 139/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0138
# Epoch 140/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0129
# Epoch 141/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0169
# Epoch 142/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0149
# Epoch 143/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0117
# Epoch 144/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0113
# Epoch 145/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0143
# Epoch 146/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0170
# Epoch 147/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0129
# Epoch 148/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0120
# Epoch 149/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0153
# Epoch 150/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0148
# Epoch 151/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0124
# Epoch 152/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0108
# Epoch 153/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0122
# Epoch 154/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0171
# Epoch 155/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0136
# Epoch 156/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0121
# Epoch 157/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0134
# Epoch 158/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0154
# Epoch 159/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0124
# Epoch 160/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0104
# Epoch 161/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0105
# Epoch 162/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0133
# Epoch 163/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0153
# Epoch 164/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0126
# Epoch 165/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0110
# Epoch 166/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0114
# Epoch 167/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0143
# Epoch 168/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0150
# Epoch 169/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0116
# Epoch 170/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0120
# Epoch 171/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0161
# Epoch 172/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0135
# Epoch 173/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0107
# Epoch 174/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0122
# Epoch 175/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0157
# Epoch 176/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0137
# Epoch 177/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0110
# Epoch 178/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0135
# Epoch 179/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0175
# Epoch 180/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0124
# Epoch 181/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0107
# Epoch 182/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0147
# Epoch 183/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0158
# Epoch 184/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0113
# Epoch 185/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0115
# Epoch 186/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0170
# Epoch 187/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0134
# Epoch 188/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0105
# Epoch 189/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0106
# Epoch 190/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0148
# Epoch 191/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0155
# Epoch 192/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0115
# Epoch 193/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0122
# Epoch 194/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0162
# Epoch 195/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0123
# Epoch 196/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0100
# Epoch 197/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0106
# Epoch 198/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0145
# Epoch 199/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0153
# Epoch 200/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0110
# 0
# Epoch 1/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1093
# Epoch 2/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1038
# Epoch 3/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0934
# Epoch 4/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0823
# Epoch 5/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0711
# Epoch 6/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0599
# Epoch 7/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0495
# Epoch 8/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0434
# Epoch 9/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0391
# Epoch 10/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0347
# Epoch 11/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0290
# Epoch 12/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0242
# Epoch 13/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0209
# Epoch 14/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0185
# Epoch 15/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0184
# Epoch 16/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0298
# Epoch 17/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0268
# Epoch 18/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0189
# Epoch 19/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0189
# Epoch 20/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0269
# Epoch 21/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0180
# Epoch 22/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0141
# Epoch 23/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0142
# Epoch 24/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0226
# Epoch 25/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0235
# Epoch 26/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0143
# Epoch 27/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0178
# Epoch 28/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0245
# Epoch 29/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0145
# Epoch 30/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0201
# Epoch 31/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0227
# Epoch 32/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0128
# Epoch 33/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0164
# Epoch 34/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0219
# Epoch 35/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0115
# Epoch 36/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0149
# Epoch 37/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0210
# Epoch 38/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0153
# Epoch 39/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0116
# Epoch 40/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0134
# Epoch 41/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0157
# Epoch 42/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0124
# Epoch 43/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0110
# Epoch 44/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0096
# Epoch 45/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0103
# Epoch 46/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0146
# Epoch 47/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0178
# Epoch 48/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0117
# Epoch 49/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0118
# Epoch 50/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0174
# Epoch 51/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0108
# Epoch 52/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0098
# Epoch 53/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0177
# Epoch 54/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0125
# Epoch 55/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0096
# Epoch 56/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0110
# Epoch 57/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0157
# Epoch 58/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0119
# Epoch 59/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0094
# Epoch 60/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0105
# Epoch 61/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0141
# Epoch 62/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0125
# Epoch 63/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0092
# Epoch 64/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0102
# Epoch 65/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0152
# Epoch 66/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0107
# Epoch 67/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0090
# Epoch 68/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0116
# Epoch 69/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0148
# Epoch 70/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0105
# Epoch 71/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0091
# Epoch 72/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0122
# Epoch 73/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0134
# Epoch 74/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0094
# Epoch 75/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0091
# Epoch 76/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0154
# Epoch 77/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0111
# Epoch 78/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0085
# Epoch 79/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0108
# Epoch 80/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0145
# Epoch 81/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0108
# Epoch 82/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0089
# Epoch 83/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0114
# Epoch 84/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0127
# Epoch 85/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0093
# Epoch 86/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0076
# Epoch 87/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0086
# Epoch 88/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0152
# Epoch 89/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0104
# Epoch 90/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0092
# Epoch 91/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0122
# Epoch 92/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0113
# Epoch 93/200
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0088
# Epoch 94/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0073
# Epoch 95/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0069
# Epoch 96/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0071
# Epoch 97/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0102
# Epoch 98/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0133
# Epoch 99/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0097
# Epoch 100/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0089
# Epoch 101/200
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0118
# Epoch 102/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0107
# Epoch 103/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0080
# Epoch 104/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0068
# Epoch 105/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0070
# Epoch 106/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0105
# Epoch 107/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0138
# Epoch 108/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0093
# Epoch 109/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0100
# Epoch 110/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0137
# Epoch 111/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0085
# Epoch 112/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0079
# Epoch 113/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0127
# Epoch 114/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0112
# Epoch 115/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0087
# Epoch 116/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0078
# Epoch 117/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0097
# Epoch 118/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0129
# Epoch 119/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0097
# Epoch 120/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0079
# Epoch 121/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0090
# Epoch 122/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0116
# Epoch 123/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0099
# Epoch 124/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0076
# Epoch 125/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0075
# Epoch 126/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0101
# Epoch 127/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0127
# Epoch 128/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0087
# Epoch 129/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0085
# Epoch 130/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0140
# Epoch 131/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0088
# Epoch 132/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0077
# Epoch 133/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0127
# Epoch 134/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0119
# Epoch 135/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0084
# Epoch 136/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0083
# Epoch 137/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0131
# Epoch 138/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0100
# Epoch 139/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0075
# Epoch 140/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0090
# Epoch 141/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0128
# Epoch 142/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0098
# Epoch 143/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0079
# Epoch 144/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0101
# Epoch 145/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0115
# Epoch 146/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0091
# Epoch 147/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0077
# Epoch 148/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0074
# Epoch 149/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0089
# Epoch 150/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0123
# Epoch 151/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0096
# Epoch 152/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0081
# Epoch 153/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0091
# Epoch 154/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0098
# Epoch 155/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0093
# Epoch 156/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0076
# Epoch 157/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0069
# Epoch 158/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0065
# Epoch 159/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0069
# Epoch 160/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0099
# Epoch 161/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0120
# Epoch 162/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0087
# Epoch 163/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0094
# Epoch 164/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0124
# Epoch 165/200
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0081
# Epoch 166/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0070
# Epoch 167/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0110
# Epoch 168/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0114
# Epoch 169/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0082
# Epoch 170/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0093
# Epoch 171/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0129
# Epoch 172/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0087
# Epoch 173/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0078
# Epoch 174/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0119
# Epoch 175/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0094
# Epoch 176/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0077
# Epoch 177/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0075
# Epoch 178/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0107
# Epoch 179/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0114
# Epoch 180/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0078
# Epoch 181/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0092
# Epoch 182/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0128
# Epoch 183/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0085
# Epoch 184/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0080
# Epoch 185/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0133
# Epoch 186/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0089
# Epoch 187/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0076
# Epoch 188/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0107
# Epoch 189/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0109
# Epoch 190/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0082
# Epoch 191/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0076
# Epoch 192/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0110
# Epoch 193/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0103
# Epoch 194/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0073
# Epoch 195/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0075
# Epoch 196/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0115
# Epoch 197/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0093
# Epoch 198/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0073
# Epoch 199/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0083
# Epoch 200/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0103
# 1
# Epoch 1/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1162
# Epoch 2/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1137
# Epoch 3/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1088
# Epoch 4/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0995
# Epoch 5/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0885
# Epoch 6/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0799
# Epoch 7/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0667
# Epoch 8/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0566
# Epoch 9/200
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0505
# Epoch 10/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0486
# Epoch 11/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0406
# Epoch 12/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0278
# Epoch 13/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0237
# Epoch 14/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0249
# Epoch 15/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0205
# Epoch 16/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0158
# Epoch 17/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0157
# Epoch 18/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0231
# Epoch 19/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0271
# Epoch 20/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0149
# Epoch 21/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0279
# Epoch 22/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0147
# Epoch 23/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0201
# Epoch 24/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0136
# Epoch 25/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0219
# Epoch 26/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0280
# Epoch 27/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0143
# Epoch 28/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0146
# Epoch 29/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0119
# Epoch 30/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0181
# Epoch 31/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0267
# Epoch 32/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0121
# Epoch 33/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0152
# Epoch 34/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0215
# Epoch 35/200
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0159
# Epoch 36/200
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0118
# Epoch 37/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0128
# Epoch 38/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0199
# Epoch 39/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0111
# Epoch 40/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0114
# Epoch 41/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0171
# Epoch 42/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0109
# Epoch 43/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0093
# Epoch 44/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0088
# Epoch 45/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0129
# Epoch 46/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0135
# Epoch 47/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0095
# Epoch 48/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0084
# Epoch 49/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0124
# Epoch 50/200
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0099
# Epoch 51/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0075
# Epoch 52/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0075
# Epoch 53/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0120
# Epoch 54/200
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0119
# Epoch 55/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0083
# Epoch 56/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0102
# Epoch 57/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0110
# Epoch 58/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0082
# Epoch 59/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0066
# Epoch 60/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0087
# Epoch 61/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0114
# Epoch 62/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0079
# Epoch 63/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0080
# Epoch 64/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0114
# Epoch 65/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0084
# Epoch 66/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0069
# Epoch 67/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0093
# Epoch 68/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0101
# Epoch 69/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0073
# Epoch 70/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0070
# Epoch 71/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0102
# Epoch 72/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0091
# Epoch 73/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0070
# Epoch 74/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0086
# Epoch 75/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0100
# Epoch 76/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0077
# Epoch 77/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0062
# Epoch 78/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0069
# Epoch 79/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0093
# Epoch 80/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0085
# Epoch 81/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0067
# Epoch 82/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0072
# Epoch 83/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0097
# Epoch 84/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0081
# Epoch 85/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0064
# Epoch 86/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0067
# Epoch 87/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0096
# Epoch 88/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0088
# Epoch 89/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0069
# Epoch 90/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0083
# Epoch 91/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0094
# Epoch 92/200
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0073
# Epoch 93/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0062
# Epoch 94/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0070
# Epoch 95/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0099
# Epoch 96/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0077
# Epoch 97/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0067
# Epoch 98/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0075
# Epoch 99/200
# 1/1 [==============================] - 0s 140ms/step - loss: 0.0077
# Epoch 100/200
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0071
# Epoch 101/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0062
# Epoch 102/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0057
# Epoch 103/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0056
# Epoch 104/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0059
# Epoch 105/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0073
# Epoch 106/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0086
# Epoch 107/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0069
# Epoch 108/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0064
# Epoch 109/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0085
# Epoch 110/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0077
# Epoch 111/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0062
# Epoch 112/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0055
# Epoch 113/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0055
# Epoch 114/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0074
# Epoch 115/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0086
# Epoch 116/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0068
# Epoch 117/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0062
# Epoch 118/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0072
# Epoch 119/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0084
# Epoch 120/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0073
# Epoch 121/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0059
# Epoch 122/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0056
# Epoch 123/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0076
# Epoch 124/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0088
# Epoch 125/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0063
# Epoch 126/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0060
# Epoch 127/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0085
# Epoch 128/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0085
# Epoch 129/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0061
# Epoch 130/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0055
# Epoch 131/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0083
# Epoch 132/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0093
# Epoch 133/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0066
# Epoch 134/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0070
# Epoch 135/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0102
# Epoch 136/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0067
# Epoch 137/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0066
# Epoch 138/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0107
# Epoch 139/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0068
# Epoch 140/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0070
# Epoch 141/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0117
# Epoch 142/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0066
# Epoch 143/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0118
# Epoch 144/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0083
# Epoch 145/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0063
# Epoch 146/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0097
# Epoch 147/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0074
# Epoch 148/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0060
# Epoch 149/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0070
# Epoch 150/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0088
# Epoch 151/200
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0079
# Epoch 152/200
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0063
# Epoch 153/200
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0066
# Epoch 154/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0086
# Epoch 155/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0073
# Epoch 156/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0058
# Epoch 157/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0059
# Epoch 158/200
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0079
# Epoch 159/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0078
# Epoch 160/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0065
# Epoch 161/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0059
# Epoch 162/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0076
# Epoch 163/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0082
# Epoch 164/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0063
# Epoch 165/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0059
# Epoch 166/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0070
# Epoch 167/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0086
# Epoch 168/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0067
# Epoch 169/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0056
# Epoch 170/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0060
# Epoch 171/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0080
# Epoch 172/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0073
# Epoch 173/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0057
# Epoch 174/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0063
# Epoch 175/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0084
# Epoch 176/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0072
# Epoch 177/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0059
# Epoch 178/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0064
# Epoch 179/200
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0074
# Epoch 180/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0070
# Epoch 181/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0059
# Epoch 182/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0055
# Epoch 183/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0062
# Epoch 184/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0082
# Epoch 185/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0071
# Epoch 186/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0061
# Epoch 187/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0067
# Epoch 188/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0076
# Epoch 189/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0065
# Epoch 190/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0053
# Epoch 191/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0053
# Epoch 192/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0073
# Epoch 193/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0079
# Epoch 194/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0062
# Epoch 195/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0061
# Epoch 196/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0080
# Epoch 197/200
# ...
# Epoch 143/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.5697
# Epoch 144/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5697
# Epoch 145/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5697
# Epoch 146/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5697
# Epoch 147/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5697
# Epoch 148/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5697
# Epoch 149/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5697
# Epoch 150/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5697
# Epoch 151/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5697
# Epoch 152/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5697
# Epoch 153/200
# 1/1 [==============================] - 0s 106ms/step - loss: 0.5697
# Epoch 154/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.5697
# Epoch 155/200
# 1/1 [==============================] - 0s 81ms/step - loss: 0.5697
# Epoch 156/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5697
# Epoch 157/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5697
# Epoch 158/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5697
# Epoch 159/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5697
# Epoch 160/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5697
# Epoch 161/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5697
# Epoch 162/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5697
# Epoch 163/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5697
# Epoch 164/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5697
# Epoch 165/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5697
# Epoch 166/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5697
# Epoch 167/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5697
# Epoch 168/200
# 1/1 [==============================] - 0s 131ms/step - loss: 0.5697
# Epoch 169/200
# 1/1 [==============================] - 0s 85ms/step - loss: 0.5697
# Epoch 170/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5697
# Epoch 171/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5697
# Epoch 172/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5701
# Epoch 173/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5697
# Epoch 174/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5697
# Epoch 175/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5697
# Epoch 176/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.5697
# Epoch 177/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5697
# Epoch 178/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5697
# Epoch 179/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5697
# Epoch 180/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5697
# Epoch 181/200
# 1/1 [==============================] - 0s 80ms/step - loss: 0.5697
# Epoch 182/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5697
# Epoch 183/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5697
# Epoch 184/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5697
# Epoch 185/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5697
# Epoch 186/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5697
# Epoch 187/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5697
# Epoch 188/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5697
# Epoch 189/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5697
# Epoch 190/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5697
# Epoch 191/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5697
# Epoch 192/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5697
# Epoch 193/200
# 1/1 [==============================] - 0s 84ms/step - loss: 0.5697
# Epoch 194/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5697
# Epoch 195/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5697
# Epoch 196/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.5697
# Epoch 197/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5697
# Epoch 198/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5697
# Epoch 199/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5697
# Epoch 200/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5697
# 57
# Epoch 1/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5253
# Epoch 2/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5253
# Epoch 3/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5253
# Epoch 4/200
# 1/1 [==============================] - 0s 77ms/step - loss: 0.5253
# Epoch 5/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5253
# Epoch 6/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.5253
# Epoch 7/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.5253
# Epoch 8/200
# 1/1 [==============================] - 0s 124ms/step - loss: 0.5253
# Epoch 9/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5253
# Epoch 10/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5253
# Epoch 11/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5253
# Epoch 12/200
# 1/1 [==============================] - 0s 217ms/step - loss: 0.5253
# Epoch 13/200
# 1/1 [==============================] - 0s 388ms/step - loss: 0.5253
# Epoch 14/200
# 1/1 [==============================] - 0s 100ms/step - loss: 0.5253
# Epoch 15/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5253
# Epoch 16/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5253
# Epoch 17/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5253
# Epoch 18/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5253
# Epoch 19/200
# 1/1 [==============================] - 0s 81ms/step - loss: 0.5253
# Epoch 20/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5253
# Epoch 21/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5253
# Epoch 22/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.5253
# Epoch 23/200
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5253
# Epoch 24/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5253
# Epoch 25/200
# 1/1 [==============================] - 0s 102ms/step - loss: 0.5253
# Epoch 26/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5253
# Epoch 27/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5253
# Epoch 28/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5253
# Epoch 29/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5253
# Epoch 30/200
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5253
# Epoch 31/200
# 1/1 [==============================] - 0s 69ms/step - loss: 0.5253
# Epoch 32/200
# 1/1 [==============================] - 0s 106ms/step - loss: 0.5253
# Epoch 33/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5253
# Epoch 34/200
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5253
# Epoch 35/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5253
# Epoch 36/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5253
# Epoch 37/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5253
# Epoch 38/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.5253
# Epoch 39/200
# 1/1 [==============================] - 0s 68ms/step - loss: 0.5253
# Epoch 40/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5253
# Epoch 41/200
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5253
# Epoch 42/200
# 1/1 [==============================] - 0s 86ms/step - loss: 0.5253
# Epoch 43/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5253
# Epoch 44/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.5253
# Epoch 45/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.5253
# Epoch 46/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5249
# Epoch 47/200
# 1/1 [==============================] - 0s 149ms/step - loss: 0.5253
# Epoch 48/200
# 1/1 [==============================] - 0s 81ms/step - loss: 0.5253
# Epoch 49/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5253
# Epoch 50/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5253
# Epoch 51/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5253
# Epoch 52/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5253
# Epoch 53/200
# 1/1 [==============================] - 0s 109ms/step - loss: 0.5253
# Epoch 54/200
# 1/1 [==============================] - 0s 99ms/step - loss: 0.5253
# Epoch 55/200
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5253
# Epoch 56/200
# 1/1 [==============================] - 0s 78ms/step - loss: 0.5253
# Epoch 57/200
# 1/1 [==============================] - 0s 127ms/step - loss: 0.5253
# Epoch 58/200
# 1/1 [==============================] - 0s 84ms/step - loss: 0.5253
# Epoch 59/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\Định Vị - ESP32\Trainning_data.ipynb Cell 4 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/%C4%90%E1%BB%8Bnh%20V%E1%BB%8B%20-%20ESP32/Trainning_data.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> train_data_i = train_data_i.numpy()
#       <a href='vscode-notebook-cell:/e%3A/%C4%90%E1%BB%8Bnh%20V%E1%BB%8B%20-%20ESP32/Trainning_data.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> train_data_i = train_data_i.reshape(1,1200)
# ----> <a href='vscode-notebook-cell:/e%3A/%C4%90%E1%BB%8Bnh%20V%E1%BB%8B%20-%20ESP32/Trainning_data.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> history = autoencoder.fit(train_data_i, train_data_i,
#       <a href='vscode-notebook-cell:/e%3A/%C4%90%E1%BB%8Bnh%20V%E1%BB%8B%20-%20ESP32/Trainning_data.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>       epochs=200,
#       <a href='vscode-notebook-cell:/e%3A/%C4%90%E1%BB%8Bnh%20V%E1%BB%8B%20-%20ESP32/Trainning_data.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>       batch_size=256,
#       <a href='vscode-notebook-cell:/e%3A/%C4%90%E1%BB%8Bnh%20V%E1%BB%8B%20-%20ESP32/Trainning_data.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>       shuffle=True)
#      <a href='vscode-notebook-cell:/e%3A/%C4%90%E1%BB%8Bnh%20V%E1%BB%8B%20-%20ESP32/Trainning_data.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> encoded_data_i = autoencoder.encoder(train_data_i).numpy()
#      <a href='vscode-notebook-cell:/e%3A/%C4%90%E1%BB%8Bnh%20V%E1%BB%8B%20-%20ESP32/Trainning_data.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> decoded_data_i = autoencoder.decoder(encoded_data_i).numpy()
#
# File c:\Users\admin\anaconda3\New folder\envs\tensorflow\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\admin\anaconda3\New folder\envs\tensorflow\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\admin\anaconda3\New folder\envs\tensorflow\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\admin\anaconda3\New folder\envs\tensorflow\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\admin\anaconda3\New folder\envs\tensorflow\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\admin\anaconda3\New folder\envs\tensorflow\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\admin\anaconda3\New folder\envs\tensorflow\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\admin\anaconda3\New folder\envs\tensorflow\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Users\admin\anaconda3\New folder\envs\tensorflow\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
df
# Out:
#         0         1         2         3         4         5         6     \
# 0   0.825060  0.832331  0.829978  0.726295  0.752083  0.744125  0.761346
# 0   0.536081  0.616004  0.694177  0.692506  0.695292  0.696007  0.598560
# 0   0.702561  0.307564  0.391144  0.373543  0.382158  0.398935  0.320835
# 0   0.513012  0.392919  0.440751  0.391351  0.584729  0.491776  0.612974
# 0   0.619400  0.541662  0.585033  0.570195  0.430311  0.407005  0.440740
# ..       ...       ...       ...       ...       ...       ...       ...
# 0  -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 0  -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 0  -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 0  -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 0  -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
#
#         7         8         9     ...      1190      1191      1192      1193  \
# 0   0.740693  0.735186  0.851384  ...  0.507409  0.521967  0.354559  0.365410
# 0   0.615638  0.607858  0.618213  ...  0.435515  0.443095  0.444665  0.229067
# 0   0.366495  0.370281  0.367314  ...  0.381094  0.358845  0.326421  0.420595
# 0   0.508595  0.508206  0.521205  ...  0.460437  0.592206  0.584250  0.589841
# 0   0.279941  0.171967  0.258118  ...  0.483250  0.457604  0.457876  0.454215
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 0  -1.000000 -1.000000 -1.000000  ... -1.000000  1.000000  1.000000  1.000000
# 0  -1.000000 -1.000000 -1.000000  ... -1.000000  1.000000  1.000000  1.000000
# 0  -1.000000 -1.000000 -1.000000  ... -1.000000  1.000000  1.000000  1.000000
# 0  -1.000000 -1.000000 -1.000000  ... -1.000000  1.000000  1.000000  1.000000
# 0  -1.000000 -1.000000 -1.000000  ... -1.000000  1.000000  1.000000  1.000000
#
#         1194      1195      1196      1197      1198      1199
# 0   0.410134  0.525597  0.417618  0.439010  0.385610  0.404374
# 0   0.272351  0.292173  0.286755  0.392300  0.426178  0.374836
# 0   0.409717  0.341336  0.427875  0.465936  0.285007  0.451086
# 0   0.605303  0.588124  0.588042  0.423389  0.431956  0.446468
# 0   0.460949  0.459988  0.455405  0.453545  0.483441  0.433605
# ..       ...       ...       ...       ...       ...       ...
# 0   1.000000 -1.000000  1.000000  1.000000  1.000000 -1.000000
# 0   1.000000 -1.000000  1.000000  1.000000  1.000000 -1.000000
# 0   1.000000 -1.000000  1.000000  1.000000  1.000000 -1.000000
# 0   1.000000 -1.000000  1.000000  1.000000  1.000000 -1.000000
# 0   1.000000 -1.000000  1.000000  1.000000  1.000000 -1.000000
#
# [75 rows x 1200 columns]

# %%
df.to_csv('E:/Định Vị - ESP32/fingerprint_test_kalman2.csv')

# %%
encoded_data1 = autoencoder.encoder(train_data1).numpy()
decoded_data1 = autoencoder.decoder(encoded_data1).numpy()
decoded_data1[0]
# Out:
# array([0.42684808, 0.52412444, 0.48928922, ..., 0.57525843, 0.5483545 ,
#        0.4727459 ], dtype=float32)

# %%
encoded_data2 = autoencoder.encoder(train_data2).numpy()
decoded_data2 = autoencoder.decoder(encoded_data2).numpy()
decoded_data2[0]
# Out:
# array([0.42684802, 0.52412504, 0.48929012, ..., 0.575259  , 0.5483548 ,
#        0.47274688], dtype=float32)

# %%
data = pd.read_csv('E:/Định Vị - ESP32/_data28_8.csv')
data = data.values
finger = pd.read_csv('E:/Định Vị - ESP32/fingerprint_train.csv')
finger = finger.iloc[: , : 1200]
finger = finger.values
min_val = np.min(data)
max_val = np.max(data)
data = (data - min_val) / (max_val - min_val)

# %%
plt.figure(figsize=(20,7))
plt.xlim(0,50)
plt.ylim(0.3,0.7)
plt.plot(finger[1],'r')
plt.plot(data[1],'b')
plt.fill_between(np.arange(1200),data[1] , finger[1], color='pink')

# %%
finger_doc = pd.read_csv('E:/Định Vị - ESP32/Finger_doc.csv')
test_doc = pd.read_csv('E:/Định Vị - ESP32/norm_new.csv')
finger_doc = finger_doc.to_numpy()
test_doc = test_doc.to_numpy()

# %%
import math

def minkowski_distance(point_a, point_b, p):
    distance_sum = 0
    for i in range(len(point_a)):
        distance_sum += abs(point_a[i] - point_b[i]) ** p
    
    distance = distance_sum ** (1 / p)
    return distance

def slide_window(arr1, arr2):
    result = []
    for i in range(0,180,30):
        segment = arr1[i:i+30]
        abs_diff = [abs(x-y)**6 for x, y in zip(segment, arr2)]
        result.append(abs_diff)

    return result

def sum_array(arr):
    arr = np.array(arr)
    arr = arr.reshape(-1, 1)
    sum = 0
    for i in range(len(arr)):
        sum = sum + arr[i]
    return sum**(1/6)

# %%
rows = 75
cols = 75
# Tạo mảng 2 chiều 75x75 với tất cả các phần tử là None
total = [[None for _ in range(cols)] for _ in range(rows)]
np.shape(total)
# Out:
# (75, 75)

# %%
for i in range(75):
    for j in range(75):
        result1 = slide_window(finger_doc[i][0:200],test_doc[j][0:30])
        result2 = slide_window(finger_doc[i][200:400],test_doc[j][30:60])
        result3 = slide_window(finger_doc[i][400:600],test_doc[j][60:90])
        result4 = slide_window(finger_doc[i][600:800],test_doc[j][90:120])
        result5 = slide_window(finger_doc[i][800:1000],test_doc[j][120:150])
        result6 = slide_window(finger_doc[i][1000:1200],test_doc[j][150:180])

        sum1 = sum_array(result1)
        sum2 = sum_array(result2)
        sum3 = sum_array(result3)
        sum4 = sum_array(result4)
        sum5 = sum_array(result5)
        sum6 = sum_array(result6)

        sum = sum1+sum2+sum3+sum4+sum5+sum6
        total[i][j] = sum
        sum = 0

np.shape(total)
# Out:
# (75, 75, 1)

# %%
total=np.array(total)
total = total.reshape(75,75)
total = pd.DataFrame(total)
total.to_csv('E:/Định Vị - ESP32/Test6_new.csv')

# %%
def find_smallest_elements_with_indices(arr, k):
    # Tạo một danh sách các cặp (giá trị, chỉ số) từ mảng
    value_index_pairs = [(value, index) for index, value in enumerate(arr)]
    
    # Sắp xếp danh sách các cặp theo giá trị
    value_index_pairs.sort()
    
    # Lấy k phần tử đầu tiên
    smallest_value_indices = value_index_pairs[:k]
    
    # Sắp xếp lại theo thứ tự chỉ số ban đầu
    smallest_value_indices.sort(key=lambda x: x[1])
    
    return smallest_value_indices

ketqua = pd.read_csv('E:/Định Vị - ESP32/Test7_new.csv')
label = pd.read_csv('E:/Định Vị - ESP32/Labels.csv')

kq = np.array(ketqua)

Delta = []

for k in range(75):
    kq_k = kq[k]

    result = find_smallest_elements_with_indices(kq_k, 3)

    for i in range(75):
        if k == label['index'][i]:
            X = label['X'][i]
            Y = label['Y'][i]
            #print(f"Tọa độ đúng: ({X} , {Y})")
    arrX = []
    arrY = []
    for value, index in result:
        for i in range(75):
            if index == label['index'][i]:
                _X = label['X'][i]
                arrX.append(_X)
                _Y = label['Y'][i]
                arrY.append(_Y)
                #print(f"Tọa độ dự đoán: ({_X} , {_Y})")
    avgX = np.mean(arrX)
    avgY = np.mean(arrY)

    delta = np.sqrt((X-avgX)**2+(Y-avgY)**2)
    Delta.append(delta)
    #print(f"Sai số: {delta}")

Delta.sort()
print(Delta[:20])
print(f"Sai số trung bình: {np.mean(Delta[:20])}")
# Out:
# [0.33333333333333304, 0.33333333333333304, 0.33333333333333326, 0.3333333333333335, 0.47140452079103157, 0.6666666666666665, 0.6666666666666667, 0.666666666666667, 0.7453559924999299, 0.7453559924999302, 0.7453559924999302, 0.9428090415820634, 0.9428090415820635, 0.9428090415820638, 0.9428090415820638, 1.0540925533894596, 1.118033988749895, 1.2018504251546633, 1.333333333333333, 1.374368541872553]
# Sai số trung bình: 0.7946860420226157

# %%
Delta
# Out:
# [0.5555555555555558,
#  0.5665577237325313,
#  0.625,
#  0.8461970117626563,
#  0.8678055195451839,
#  1.0061539042374907,
#  1.1111111111111107,
#  1.1811273125260724,
#  1.4487116456005888,
#  1.6814162167135065,
#  1.7356110390903672,
#  1.7568209223157665,
#  1.8324913891634047,
#  1.885618083164127,
#  1.8921540406584894,
#  2.0875882475617704,
#  2.1213203435596424,
#  2.2054925823643563,
#  2.21387320501903,
#  2.222222222222222,
#  2.224998266055643,
#  2.2498285257018424,
#  2.2980970388562794,
#  2.354402233379677,
#  2.3934065809486684,
#  2.4368569110512563,
#  2.4444444444444446,
#  2.496911672693803,
#  2.536158269002962,
#  2.5579698740491863,
#  2.6010444246043614,
#  2.671292284482513,
#  2.7442420078285483,
#  2.752839443193155,
#  2.7777777777777777,
#  2.8327886186626583,
#  2.8974232912011773,
#  3.0020569080236212,
#  3.0020569080236212,
#  3.0651364942519383,
#  3.0872097754332897,
#  3.094854600784987,
#  3.2451293036689406,
#  3.2829526005987018,
#  3.290465087769077,
#  3.3035708327374453,
#  3.384788047050625,
#  3.3920750049941666,
#  3.4889596595794625,
#  3.508367423077099,
#  3.5311663515712675,
#  3.5832256659104664,
#  3.6328406053937363,
#  3.6801100359287098,
#  3.6817870057290865,
#  3.733399470313654,
#  3.7728726325221436,
#  3.7728726325221436,
#  3.8809442659051068,
#  4.0154024443539225,
#  4.039924213932854,
#  4.085505846855608,
#  4.129089816902677,
#  4.18846151666017,
#  4.334757600695814,
#  4.5229183193439155,
#  4.6040776344668135,
#  4.7984050848198185,
#  4.893936787898943,
#  4.931631338038255,
#  5.194964323360427,
#  5.425135829214979,
#  5.425135829214979,
#  5.448977704550768,
#  5.735959777395692]

# %%
df = pd.read_csv("E:/Định Vị - ESP32/test0.csv")

dfx = df['1'][0:200].to_list()+df['2'][0:200].to_list()
len(dfx)
# Out:
# 400

# %%
new_df = []
for i in range(0,15000,200):
    df_i = df['1'][i:i+200].to_list()+df['2'][i:i+200].to_list()+df['3'][i:i+200].to_list()+df['4'][i:i+200].to_list()+df['5'][i:i+200].to_list()+df['6'][i:i+200].to_list()
    new_df.append(df_i)
np.shape(new_df)
new_df = np.array(new_df)
new_df = pd.DataFrame(new_df)
new_df.to_csv('E:/Định Vị - ESP32/new_test.csv')

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]

result_list = list1 + list2

print(result_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
data28_8 = pd.read_csv('E:/Định Vị - ESP32/_data28_8.csv')
data = data28_8.values
data
# Out:
# array([[-67, -68, -67, ..., -82, -82, -85],
#        [-83, -82, -82, ..., -86, -85, -85],
#        [-82, -76, -78, ..., -85, -84, -87],
#        ...,
#        [-83, -79, -79, ..., -87, -86, -87],
#        [-89, -89, -91, ..., -85, -80, -86],
#        [-81, -81, -81, ..., -83, -83, -82]], dtype=int64)

# %%
new = []
for i in range(75):
    selected_elements = []

    # Các khoảng đã chỉ định
    ranges = [(0, 200), (200, 400), (400, 600), (600, 800), (800, 1000), (1000, 1200)]

    # Lặp qua từng khoảng và lấy ngẫu nhiên 30 phần tử
    for start, end in ranges:
        random_indices = np.random.choice(np.arange(start, end), size=30, replace=False)
        selected_elements.extend(data[i][random_indices])
    new.append(selected_elements)

# %%
new = pd.DataFrame(new)
new.to_csv('E:/Định Vị - ESP32/new.csv')

# %%
finger_doc = pd.read_csv('E:/Định Vị - ESP32/fingerprint_train.csv')
test_doc = pd.read_csv('E:/Định Vị - ESP32/fingerprint_test.csv')
finger_doc = finger_doc.to_numpy()
test_doc = test_doc.to_numpy()

def minkowski_distance(point_a, point_b, p):
    distance_sum = 0
    for i in range(len(point_a)):
        distance_sum += abs(point_a[i] - point_b[i]) ** p
    
    distance = distance_sum ** (1 / p)
    return distance

def sum_array(arr):
    arr = np.array(arr)
    arr = arr.reshape(-1, 1)
    sum = 0
    for i in range(len(arr)):
        sum = sum + arr[i]
    return sum

rows = 75
cols = 75
# Tạo mảng 2 chiều 75x75 với tất cả các phần tử là None
total = [[None for _ in range(cols)] for _ in range(rows)]

for i in range(75):
    for j in range(75):
        distance = minkowski_distance(test_doc[j],finger_doc[i],12)
        sum = np.sum(distance)
        total[j][i]=sum
        
#total=np.array(total)
#total = total.reshape(75,75)
#total = pd.DataFrame(total)
#total.to_csv('E:/Định Vị - ESP32/Test_x1.csv')      


def find_smallest_elements_with_indices(arr, k):
    # Tạo một danh sách các cặp (giá trị, chỉ số) từ mảng
    value_index_pairs = [(value, index) for index, value in enumerate(arr)]
    
    # Sắp xếp danh sách các cặp theo giá trị
    value_index_pairs.sort()
    
    # Lấy k phần tử đầu tiên
    smallest_value_indices = value_index_pairs[:k]
    
    # Sắp xếp lại theo thứ tự chỉ số ban đầu
    #smallest_value_indices.sort(key=lambda x: x[1])
    
    return smallest_value_indices

#ketqua = pd.read_csv('E:/Định Vị - ESP32/Test_x1.csv')
label = pd.read_csv('E:/Định Vị - ESP32/Labels.csv')
#ketqua = ketqua.iloc[:75,1:76]
kq = total
#kq = np.array(ketqua)

Delta = []

for k in range(75):
    kq_k = kq[k]

    result = find_smallest_elements_with_indices(kq_k,4)

    for i in range(75):
        if k == label['index'][i]:
            X = label['X'][i]
            Y = label['Y'][i]
            #print(f"Tọa độ đúng: ({X} , {Y})")
    arrX = []
    arrY = []
    for value, index in result:
        for i in range(75):
            if index == label['index'][i]:
                _X = label['X'][i]
                arrX.append(_X)
                _Y = label['Y'][i]
                arrY.append(_Y)
                #print(f"Tọa độ dự đoán: ({_X} , {_Y})")
    avgX = np.mean(arrX)
    avgY = np.mean(arrY)

    delta = np.sqrt((X-avgX)**2+(Y-avgY)**2)
    Delta.append(delta)
    #print(f"Sai số: {delta}")

Delta = find_smallest_elements_with_indices(Delta,75)
Delta = Delta[40:75]
D = pd.DataFrame(Delta)
D
# Out:
#            0   1
# 0   3.051639  57
# 1   3.092329  20
# 2   3.132491  68
# 3   3.162278  43
# 4   3.162278  60
# 5   3.181981  35
# 6   3.354102  32
# 7   3.354102  44
# 8   3.354102  45
# 9   3.482097  40
# 10  3.579455  67
# 11  3.750000  23
# 12  3.881044  29
# 13  3.952847  21
# 14  4.031129  28
# 15  4.190764  31
# 16  4.257347  17
# 17  4.272002   5
# 18  4.301163  19
# 19  4.315669  58
# 20  4.589390  69
# 21  4.756574   4
# 22  5.031153  26
# 23  5.153882  16
# 24  5.297405   6
# 25  5.350234   9
# 26  5.460082   2
# 27  5.830952  22
# 28  5.830952  24
# 29  6.149187   1
# 30  6.309715  10
# 31  6.408003  15
# 32  6.500000  33
# 33  6.828250  12
# 34  6.932712   3

# %%
finger_doc = pd.read_csv('E:/Định Vị - ESP32/fingerprint_train.csv')
test_doc = pd.read_csv('E:/Định Vị - ESP32/fingerprint_test - Copy.csv')

finger_doc = finger_doc.to_numpy()
test_doc = test_doc.iloc[:12,1:1201]
test_doc = test_doc.to_numpy()

def minkowski_distance(point_a, point_b, p):
    distance_sum = 0
    for i in range(len(point_a)):
        distance_sum += abs(point_a[i] - point_b[i]) ** p
    
    distance = distance_sum ** (1 / p)
    return distance

def sum_array(arr):
    arr = np.array(arr)
    arr = arr.reshape(-1, 1)
    sum = 0
    for i in range(len(arr)):
        sum = sum + arr[i]
    return sum

rows = 12
cols = 75
# Tạo mảng 2 chiều 75x75 với tất cả các phần tử là None
total = [[None for _ in range(cols)] for _ in range(rows)]

for i in range(75):
    for j in range(12):
        distance = minkowski_distance(test_doc[j],finger_doc[i],12)
        sum = np.sum(distance)
        total[j][i]=sum
        
#total = np.array(total)
#total = total.reshape(20,75)
#total = pd.DataFrame(total)
#total.to_csv('E:/Định Vị - ESP32/Test_x1.csv')  
    

def find_smallest_elements_with_indices(arr, k):
    # Tạo một danh sách các cặp (giá trị, chỉ số) từ mảng
    value_index_pairs = [(value, index) for index, value in enumerate(arr)]
    
    # Sắp xếp danh sách các cặp theo giá trị
    value_index_pairs.sort()
    
    # Lấy k phần tử đầu tiên
    smallest_value_indices = value_index_pairs[:k]
    
    # Sắp xếp lại theo thứ tự chỉ số ban đầu
    #smallest_value_indices.sort(key=lambda x: x[1])
    
    return smallest_value_indices

#ketqua = total
label_train = pd.read_csv('E:/Định Vị - ESP32/Labels.csv')
label_test = pd.read_csv('E:/Định Vị - ESP32/Labels_test.csv')
#kq = ketqua.iloc[:20,1:76]
#kq = np.array(ketqua)
kq = total


Delta = []
for i in range(12):
    for j in range(75):
        if label_test['index'][i]  == label_train['index'][j]:
            X = label_train['X'][j]
            Y = label_train['Y'][j]
    
    result = find_smallest_elements_with_indices(kq[i],6)
    arrX = []
    arrY = []

    for value, index in result:
        for k in range(75):
            if index == label_train['index'][k]:
                _X = label_train['X'][k]
                arrX.append(_X)
                _Y = label_train['Y'][k]
                arrY.append(_Y)
    avgX = np.mean(arrX)
    avgY = np.mean(arrY)

    delta = np.sqrt((X-avgX)**2+(Y-avgY)**2)
    Delta.append(delta)

Delta = find_smallest_elements_with_indices(Delta,12) 

"""sum = 0
for i in range(12):
    sum = sum + Delta[i][0]
print(sum/12)"""

D = []
for i in range(12):
    D.append(Delta[i][0])
D = pd.DataFrame(D)
D
# Out:
#            0
# 0   0.527046
# 1   1.178511
# 2   2.192158
# 3   2.266912
# 4   2.603417
# 5   2.773886
# 6   3.041381
# 7   3.064129
# 8   3.236081
# 9   3.236081
# 10  3.374743
# 11  3.961621

# %%
result = find_smallest_elements_with_indices(kq[10],5)
result
# Out:
# [(0.9667722442792722, 12),
#  (1.20522555365755, 17),
#  (1.3744964494594027, 21),
#  (1.129451748164847, 32),
#  (0.7943799049111476, 39)]

# %%
label_train
# Out:
#     index  X  Y
# 0       0  1  0
# 1       1  2  0
# 2       2  3  0
# 3       3  4  0
# 4       4  5  0
# ..    ... .. ..
# 70     70  3  8
# 71     71  4  8
# 72     72  5  8
# 73     73  6  8
# 74     74  7  8
#
# [75 rows x 3 columns]

# %%
train = pd.read_csv('E:/Định Vị - ESP32/fingerprint_train.csv')
#test = pd.read_csv('E:/Định Vị - ESP32/fingerprint_test_CAE_Kalman2 - Copy.csv')
test = pd.read_csv('E:/Định Vị - ESP32/AE_test_13_9.csv')
label = pd.read_csv('E:/Định Vị - ESP32/Labels.csv')
#test = test.iloc[:20,1:1201]
train = train.to_numpy()
test  = test.to_numpy()

def normalized_cross_correlation(x, y):
    numerator = np.sum(x * y)
    denominator = np.sqrt(np.sum(x**2)) * np.sqrt(np.sum(y**2))
    return numerator / denominator
    

def find_max_elements_with_indices(arr, k):
    # Tạo một danh sách các cặp (giá trị, chỉ số) từ mảng
    value_index_pairs = [(value, index) for index, value in enumerate(arr)]
    
    # Sắp xếp danh sách các cặp theo giá trị
    value_index_pairs.sort(reverse=True)
    
    # Lấy k phần tử đầu tiên
    max_value_indices = value_index_pairs[:k]
    
    # Sắp xếp lại theo thứ tự chỉ số ban đầu
    #max_value_indices.sort(key=lambda x: x[1])
    
    return max_value_indices

A = []
for i in range(75):
    corr = normalized_cross_correlation(test[2],train[i])
    A.append(corr)
B = find_max_elements_with_indices(A,10)
B
# Out:
# [(0.9642922492129179, 46),
#  (0.9628969509147371, 69),
#  (0.9620485990730706, 67),
#  (0.9578527493247244, 62),
#  (0.9555598237151746, 43),
#  (0.9545131318437955, 38),
#  (0.9538614970859429, 41),
#  (0.9538035962991402, 30),
#  (0.9530247922952266, 27),
#  (0.952422749838457, 71)]

# %%
import numpy as np

# Tạo hai vector x[n] và y[n] (ví dụ)
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 5, 3, 4, 5])

# Tính độ dài của hai vector
N = len(x)

# Khởi tạo mảng để lưu tương quan chéo
cross_correlation = np.zeros(N)

# Tính tương quan chéo
for k in range(N):
    cross_correlation[k] = np.sum(x * np.roll(y, k))

# In kết quả
print("Tương quan chéo giữa x và y:")
print(cross_correlation)
np.mean(cross_correlation)
# Out:
# Tương quan chéo giữa x và y:
# [61. 54. 52. 55. 48.]
# 54.0
